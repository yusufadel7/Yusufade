# %%
# Importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from random import shuffle
import warnings
#import statsmodels.api as sm
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree  import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn import svm
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import RocCurveDisplay
from sklearn.model_selection import GridSearchCV
from mlxtend.plotting import plot_confusion_matrix
from sklearn.ensemble import GradientBoostingClassifier
import xgboost as xgb
import lightgbm as lgb
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import RidgeClassifier





# Turn off the warnings.
warnings.filterwarnings(action='ignore')
# %matplotlib inline

# %% [markdown]
# # EDA

# %%
# Importing the dataset
df=pd.read_csv("credit_train.csv",na_values=['x'])
df
# Out:
#        Unnamed: 0      ID Customer_ID    Month       Name   Age          SSN  \
# 0           46184   74905  CUS_0xbbda   August  le Stevem    50  598-28-8368
# 1           63927  101520  CUS_0x1e51     July   Raymondl    32  887-23-0031
# 2           65974  104591  CUS_0x1765     June     Harryw    32  966-30-5287
# 3           68006  107639  CUS_0x751c     June   Jessican    19  220-63-1416
# 4           84461  132322  CUS_0x1c59      May       Dayz    41  277-13-7658
# ...           ...     ...         ...      ...        ...   ...          ...
# 54735       47297   76578  CUS_0xb443  January    Kerbere    21    #F%$D@*&8
# 54736       14571   27488  CUS_0x36ed    March     Carewn    32  398-22-8099
# 54737       43014   70151  CUS_0x204b     June       Nius    31  893-44-1748
# 54738       85052  133209  CUS_0x3c97    April  Tetsushiz    44  856-06-6147
# 54739       67901  107482  CUS_0xc150      May    Josepht  7255  154-13-2333
#
#          Occupation Annual_Income  Monthly_Inhand_Salary  ...  Credit_Mix  \
# 0           Manager      72099.14            5842.350694  ...        Good
# 1      Entrepreneur      17443.94            1714.661667  ...         Bad
# 2           _______     15186.175            1527.514583  ...    Standard
# 3        Accountant     177696.92           15090.076667  ...        Good
# 4            Doctor     19188.055            1358.004583  ...           _
# ...             ...           ...                    ...  ...         ...
# 54735        Doctor    21271789.0           12452.330000  ...    Standard
# 54736     Developer       28452.8            2267.066667  ...           _
# 54737      Mechanic      52256.67            4322.722500  ...           _
# 54738    Journalist      9741.195            1097.766250  ...           _
# 54739        Lawyer       31016.6            2653.716667  ...        Good
#
#        Outstanding_Debt  Credit_Utilization_Ratio      Credit_History_Age  \
# 0               1421.95                 35.960435   28 Years and 2 Months
# 1               2816.57                 35.515016   11 Years and 5 Months
# 2                  9.70                 36.578680   23 Years and 7 Months
# 3               1182.91                 35.080063  25 Years and 10 Months
# 4                464.09                 28.878950   22 Years and 6 Months
# ...                 ...                       ...                     ...
# 54735           1205.02                 26.343072  26 Years and 10 Months
# 54736           1909.79                 27.733014   18 Years and 1 Months
# 54737           2109.67                 40.760453    9 Years and 0 Months
# 54738            582.95                 31.234320   26 Years and 6 Months
# 54739            143.75                 34.153812   19 Years and 9 Months
#
#       Payment_of_Min_Amount  Total_EMI_per_month Amount_invested_monthly  \
# 0                        NM           426.797077              417.148202
# 1                       Yes            55.673626               37.777137
# 2                        No            10.915070               53.306883
# 3                        No            74.732590             1283.649824
# 4                        No            44.602370               47.128123
# ...                     ...                  ...                     ...
# 54735                    No           224.631416              858.769871
# 54736                   Yes           106.584142               96.054678
# 54737                   Yes            82.844023              138.755825
# 54738                   Yes            13.376546               93.395907
# 54739                    No            15.449407              112.286099
#
#                      Payment_Behaviour     Monthly_Balance Credit_Score
# 0       Low_spent_Small_value_payments   290.8918608420343          1.0
# 1      High_spent_Small_value_payments    338.015403853136          NaN
# 2       Low_spent_Small_value_payments   378.5295055439751          NaN
# 3      Low_spent_Medium_value_payments  430.62525257098235          NaN
# 4       Low_spent_Large_value_payments  314.06996555020623          1.0
# ...                                ...                 ...          ...
# 54735   Low_spent_Small_value_payments   451.8317125065498          NaN
# 54736   Low_spent_Small_value_payments  314.06784670954283          NaN
# 54737  Low_spent_Medium_value_payments   490.6724020757467          0.0
# 54738   Low_spent_Small_value_payments  293.00417234279536          NaN
# 54739   Low_spent_Large_value_payments  407.63616143977373          1.0
#
# [54740 rows x 29 columns]

# %% [markdown]
# ## Data Understanding

# %%
# Showing the first 5 rows
df.head(5)
# Out:
#    Unnamed: 0      ID Customer_ID   Month       Name Age          SSN  \
# 0       46184   74905  CUS_0xbbda  August  le Stevem  50  598-28-8368
# 1       63927  101520  CUS_0x1e51    July   Raymondl  32  887-23-0031
# 2       65974  104591  CUS_0x1765    June     Harryw  32  966-30-5287
# 3       68006  107639  CUS_0x751c    June   Jessican  19  220-63-1416
# 4       84461  132322  CUS_0x1c59     May       Dayz  41  277-13-7658
#
#      Occupation Annual_Income  Monthly_Inhand_Salary  ...  Credit_Mix  \
# 0       Manager      72099.14            5842.350694  ...        Good
# 1  Entrepreneur      17443.94            1714.661667  ...         Bad
# 2       _______     15186.175            1527.514583  ...    Standard
# 3    Accountant     177696.92           15090.076667  ...        Good
# 4        Doctor     19188.055            1358.004583  ...           _
#
#    Outstanding_Debt  Credit_Utilization_Ratio      Credit_History_Age  \
# 0           1421.95                 35.960435   28 Years and 2 Months
# 1           2816.57                 35.515016   11 Years and 5 Months
# 2              9.70                 36.578680   23 Years and 7 Months
# 3           1182.91                 35.080063  25 Years and 10 Months
# 4            464.09                 28.878950   22 Years and 6 Months
#
#   Payment_of_Min_Amount  Total_EMI_per_month Amount_invested_monthly  \
# 0                    NM           426.797077              417.148202
# 1                   Yes            55.673626               37.777137
# 2                    No            10.915070               53.306883
# 3                    No            74.732590             1283.649824
# 4                    No            44.602370               47.128123
#
#                  Payment_Behaviour     Monthly_Balance Credit_Score
# 0   Low_spent_Small_value_payments   290.8918608420343          1.0
# 1  High_spent_Small_value_payments    338.015403853136          NaN
# 2   Low_spent_Small_value_payments   378.5295055439751          NaN
# 3  Low_spent_Medium_value_payments  430.62525257098235          NaN
# 4   Low_spent_Large_value_payments  314.06996555020623          1.0
#
# [5 rows x 29 columns]

# %%
# Showing the columns
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN',
#        'Occupation', 'Annual_Income', 'Monthly_Inhand_Salary',
#        'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan',
#        'Type_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment',
#        'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Credit_Mix',
#        'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
# Show the value counts
df['Customer_ID'].value_counts()
# Out:
# CUS_0x7403    8
# CUS_0xc065    8
# CUS_0x7223    8
# CUS_0x527c    8
# CUS_0x41de    8
#              ..
# CUS_0xb975    1
# CUS_0x7884    1
# CUS_0x25fd    1
# CUS_0x8c8d    1
# CUS_0x1a96    1
# Name: Customer_ID, Length: 12479, dtype: int64

# %%
# Showing the info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54740 entries, 0 to 54739
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                54740 non-null  int64
#  1   ID                        54740 non-null  int64
#  2   Customer_ID               54740 non-null  object
#  3   Month                     54740 non-null  object
#  4   Name                      49213 non-null  object
#  5   Age                       54740 non-null  object
#  6   SSN                       54740 non-null  object
#  7   Occupation                54740 non-null  object
#  8   Annual_Income             54740 non-null  object
#  9   Monthly_Inhand_Salary     54740 non-null  float64
#  10  Num_Bank_Accounts         54740 non-null  int64
#  11  Num_Credit_Card           54740 non-null  int64
#  12  Interest_Rate             54740 non-null  int64
#  13  Num_of_Loan               54740 non-null  object
#  14  Type_of_Loan              48488 non-null  object
#  15  Delay_from_due_date       54740 non-null  int64
#  16  Num_of_Delayed_Payment    50910 non-null  object
#  17  Changed_Credit_Limit      54740 non-null  object
#  18  Num_Credit_Inquiries      54740 non-null  int64
#  19  Credit_Mix                54740 non-null  object
#  20  Outstanding_Debt          54740 non-null  float64
#  21  Credit_Utilization_Ratio  54740 non-null  float64
#  22  Credit_History_Age        54740 non-null  object
#  23  Payment_of_Min_Amount     54740 non-null  object
#  24  Total_EMI_per_month       54740 non-null  float64
#  25  Amount_invested_monthly   54740 non-null  float64
#  26  Payment_Behaviour         54740 non-null  object
#  27  Monthly_Balance           54091 non-null  object
#  28  Credit_Score              25588 non-null  float64
# dtypes: float64(6), int64(7), object(16)
# memory usage: 12.1+ MB

# %%
# Drop the columns
df.drop(columns=['Customer_ID','ID'],inplace=True)

# %%
# Drop the column
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
# check shape
df.shape
# Out:
# (54740, 26)

# %%
# check duplicate
df.duplicated().sum()
# Out:
# 0

# %%
# describe the dataset
df.describe()
# Out:
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# count           54740.000000       54740.000000     54740.000000
# mean             4205.106827          16.634710        22.909847
# std              3186.265970         114.924728       130.295385
# min               303.645417          -1.000000         0.000000
# 25%              1630.701667           3.000000         4.000000
# 50%              3107.820417           6.000000         6.000000
# 75%              5981.988333           7.000000         7.000000
# max             15204.633333        1798.000000      1499.000000
#
#        Interest_Rate  Delay_from_due_date  Num_Credit_Inquiries  \
# count   54740.000000         54740.000000          54740.000000
# mean       74.188071            21.054512             27.592218
# std       473.022799            14.840879            192.130784
# min         1.000000            -5.000000              0.000000
# 25%         8.000000            10.000000              3.000000
# 50%        13.000000            18.000000              6.000000
# 75%        20.000000            28.000000              9.000000
# max      5789.000000            67.000000           2594.000000
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Total_EMI_per_month  \
# count      54740.000000              54740.000000         54740.000000
# mean        1424.694102                 32.281263          1411.066778
# std         1153.240584                  5.111356          8305.102900
# min            0.230000                 20.172942             0.000000
# 25%          566.080000                 28.054546            30.201032
# 50%         1165.265000                 32.317994            69.436189
# 75%         1941.930000                 36.490079           160.392925
# max         4998.070000                 49.564519         82331.000000
#
#        Amount_invested_monthly  Credit_Score
# count             54740.000000  25588.000000
# mean                195.913926      0.379787
# std                 199.740666      0.485343
# min                   0.000000      0.000000
# 25%                  72.183624      0.000000
# 50%                 129.198295      0.000000
# 75%                 237.892531      1.000000
# max                1977.326102      1.000000

# %%
#count the number of missing values in each column.
df.isnull().sum()
# Out:
# Month                           0
# Name                         5527
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary           0
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                 6252
# Delay_from_due_date             0
# Num_of_Delayed_Payment       3830
# Changed_Credit_Limit            0
# Num_Credit_Inquiries            0
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age              0
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly         0
# Payment_Behaviour               0
# Monthly_Balance               649
# Credit_Score                29152
# dtype: int64

# %%
# adjust the figure size
plt.figure(figsize=(35,10))
#plotting the countplot
sns.countplot(x=df['Credit_Score']).set(title='Attacks and subtypes')
# Out:
# [Text(0.5, 1.0, 'Attacks and subtypes')]

# %%
# Showing the info 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54740 entries, 0 to 54739
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month                     54740 non-null  object
#  1   Name                      49213 non-null  object
#  2   Age                       54740 non-null  object
#  3   SSN                       54740 non-null  object
#  4   Occupation                54740 non-null  object
#  5   Annual_Income             54740 non-null  object
#  6   Monthly_Inhand_Salary     54740 non-null  float64
#  7   Num_Bank_Accounts         54740 non-null  int64
#  8   Num_Credit_Card           54740 non-null  int64
#  9   Interest_Rate             54740 non-null  int64
#  10  Num_of_Loan               54740 non-null  object
#  11  Type_of_Loan              48488 non-null  object
#  12  Delay_from_due_date       54740 non-null  int64
#  13  Num_of_Delayed_Payment    50910 non-null  object
#  14  Changed_Credit_Limit      54740 non-null  object
#  15  Num_Credit_Inquiries      54740 non-null  int64
#  16  Credit_Mix                54740 non-null  object
#  17  Outstanding_Debt          54740 non-null  float64
#  18  Credit_Utilization_Ratio  54740 non-null  float64
#  19  Credit_History_Age        54740 non-null  object
#  20  Payment_of_Min_Amount     54740 non-null  object
#  21  Total_EMI_per_month       54740 non-null  float64
#  22  Amount_invested_monthly   54740 non-null  float64
#  23  Payment_Behaviour         54740 non-null  object
#  24  Monthly_Balance           54091 non-null  object
#  25  Credit_Score              25588 non-null  float64
# dtypes: float64(6), int64(5), object(15)
# memory usage: 10.9+ MB

# %%
#adjust the figure size
plt.figure(figsize=(35,10))
#plotting the countplot 
sns.countplot(x=df['Month'],hue=df['Credit_Score']).set(title='Attacks and subtypes')
# Out:
# [Text(0.5, 1.0, 'Attacks and subtypes')]

# %% [markdown]
# # preprocessing data

# %%
# check null values
df.isnull().sum()
# Out:
# Month                           0
# Name                         5527
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary           0
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                 6252
# Delay_from_due_date             0
# Num_of_Delayed_Payment       3830
# Changed_Credit_Limit            0
# Num_Credit_Inquiries            0
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age              0
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly         0
# Payment_Behaviour               0
# Monthly_Balance               649
# Credit_Score                29152
# dtype: int64

# %%
# Showing the info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54740 entries, 0 to 54739
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month                     54740 non-null  object
#  1   Name                      49213 non-null  object
#  2   Age                       54740 non-null  object
#  3   SSN                       54740 non-null  object
#  4   Occupation                54740 non-null  object
#  5   Annual_Income             54740 non-null  object
#  6   Monthly_Inhand_Salary     54740 non-null  float64
#  7   Num_Bank_Accounts         54740 non-null  int64
#  8   Num_Credit_Card           54740 non-null  int64
#  9   Interest_Rate             54740 non-null  int64
#  10  Num_of_Loan               54740 non-null  object
#  11  Type_of_Loan              48488 non-null  object
#  12  Delay_from_due_date       54740 non-null  int64
#  13  Num_of_Delayed_Payment    50910 non-null  object
#  14  Changed_Credit_Limit      54740 non-null  object
#  15  Num_Credit_Inquiries      54740 non-null  int64
#  16  Credit_Mix                54740 non-null  object
#  17  Outstanding_Debt          54740 non-null  float64
#  18  Credit_Utilization_Ratio  54740 non-null  float64
#  19  Credit_History_Age        54740 non-null  object
#  20  Payment_of_Min_Amount     54740 non-null  object
#  21  Total_EMI_per_month       54740 non-null  float64
#  22  Amount_invested_monthly   54740 non-null  float64
#  23  Payment_Behaviour         54740 non-null  object
#  24  Monthly_Balance           54091 non-null  object
#  25  Credit_Score              25588 non-null  float64
# dtypes: float64(6), int64(5), object(15)
# memory usage: 10.9+ MB

# %%
# Droping the null values
df.dropna(inplace=True)

# %%
# check null values
df.isnull().sum()
# Out:
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
# Showing the head
df.head(5)
# Out:
#      Month            Name Age          SSN  Occupation Annual_Income  \
# 0   August       le Stevem  50  598-28-8368     Manager      72099.14
# 4      May            Dayz  41  277-13-7658      Doctor     19188.055
# 6    March    Sue Zeidlerd  37  267-54-6899  Journalist      21093.41
# 8      May  Giorgio Gavinu  26  206-94-5126      Doctor      20958.75
# 13   April     McLaughlinc  23  590-91-7790     _______      15937.74
#
#     Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  \
# 0             5842.350694                  4                3              2
# 4             1358.004583                  5                4              2
# 6             1677.784167                  1                5             10
# 8             1470.562500                  9                9             21
# 13            1144.145000                  9                9           2703
#
#     ... Credit_Mix Outstanding_Debt  Credit_Utilization_Ratio  \
# 0   ...       Good          1421.95                 35.960435
# 4   ...          _           464.09                 28.878950
# 6   ...       Good           694.73                 25.494067
# 8   ...        Bad          1310.95                 23.304684
# 13  ...          _          2432.09                 33.232912
#
#         Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 0    28 Years and 2 Months                    NM           426.797077
# 4    22 Years and 6 Months                    No            44.602370
# 6   26 Years and 11 Months                    No            29.959037
# 8    18 Years and 5 Months                   Yes           130.528737
# 13   12 Years and 7 Months                   Yes            38.417517
#
#    Amount_invested_monthly                 Payment_Behaviour  \
# 0               417.148202    Low_spent_Small_value_payments
# 4                47.128123    Low_spent_Large_value_payments
# 6                30.709461  High_spent_Medium_value_payments
# 8                35.144850  High_spent_Medium_value_payments
# 13               60.294603    Low_spent_Large_value_payments
#
#        Monthly_Balance Credit_Score
# 0    290.8918608420343          1.0
# 4   314.06996555020623          1.0
# 6     357.109919252976          1.0
# 8   231.38266329995997          0.0
# 13   285.7023805962588          0.0
#
# [5 rows x 26 columns]

# %% [markdown]
# # encoding

# %%
# Select the categorical columns
categorical_columns = df.select_dtypes(include=['object', 'category']).columns
categorical_columns
# Out:
# Index(['Month', 'Name', 'Age', 'SSN', 'Occupation', 'Annual_Income',
#        'Num_of_Loan', 'Type_of_Loan', 'Num_of_Delayed_Payment',
#        'Changed_Credit_Limit', 'Credit_Mix', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Payment_Behaviour', 'Monthly_Balance'],
#       dtype='object')

# %%
# Import LabelEncoder
from sklearn.preprocessing import LabelEncoder
for col in categorical_columns:
    # Convert all values in the column to strings
    df[col] = df[col].astype(str)

    # Initialize LabelEncoder
    le = LabelEncoder()

    # Fit and transform the column
    df[col] = le.fit_transform(df[col])

# %%
# Droping the Name column
df.drop(columns=['Name'],inplace=True)

# %%
# Show the info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18968 entries, 0 to 54734
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month                     18968 non-null  int32
#  1   Age                       18968 non-null  int32
#  2   SSN                       18968 non-null  int32
#  3   Occupation                18968 non-null  int32
#  4   Annual_Income             18968 non-null  int32
#  5   Monthly_Inhand_Salary     18968 non-null  float64
#  6   Num_Bank_Accounts         18968 non-null  int64
#  7   Num_Credit_Card           18968 non-null  int64
#  8   Interest_Rate             18968 non-null  int64
#  9   Num_of_Loan               18968 non-null  int32
#  10  Type_of_Loan              18968 non-null  int32
#  11  Delay_from_due_date       18968 non-null  int64
#  12  Num_of_Delayed_Payment    18968 non-null  int32
#  13  Changed_Credit_Limit      18968 non-null  int32
#  14  Num_Credit_Inquiries      18968 non-null  int64
#  15  Credit_Mix                18968 non-null  int32
#  16  Outstanding_Debt          18968 non-null  float64
#  17  Credit_Utilization_Ratio  18968 non-null  float64
#  18  Credit_History_Age        18968 non-null  int32
#  19  Payment_of_Min_Amount     18968 non-null  int32
#  20  Total_EMI_per_month       18968 non-null  float64
#  21  Amount_invested_monthly   18968 non-null  float64
#  22  Payment_Behaviour         18968 non-null  int32
#  23  Monthly_Balance           18968 non-null  int32
#  24  Credit_Score              18968 non-null  float64
# dtypes: float64(6), int32(14), int64(5)
# memory usage: 2.7 MB

# %% [markdown]
# # feature engineering

# %%
# dropping the 'Credit_Score' column from the df
df_features = df.drop(columns=["Credit_Score"])

# %%
# Assign the features DataFrame to 'X' and the target variable 'Credit_Score' to 'y' 
X = df_features
y = df["Credit_Score"]

# %%
# Split the dataset into training and testing sets.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.3,
                                                    random_state=3,
                                                    shuffle=True)
len(X_train), len(X_test), len(y_train), len(y_test)
# Out:
# (13277, 5691, 13277, 5691)

# %%
# Initialize the RobustScaler to scale the features by removing the median 
# and scaling the data according to the Interquartile Range (IQR).
# Fit the scaler on the training data and transform both the training and testing sets.
Ro_scaler = RobustScaler()
X_train = Ro_scaler.fit_transform(X_train)  # Fit and transform the training data
X_test = Ro_scaler.transform(X_test)        # Transform the testing data using the fitted scaler

# %%
from sklearn.feature_selection import RFE, SelectKBest, chi2
# Ensure all values in X are non-negative by adding a constant
X_transformed = X - X.min().min()

# Perform Chi-Square test
chi2_stat, p_values = chi2(X_transformed, y)

# Create a DataFrame to display the results
chi2_results = pd.DataFrame({
    'Feature': X.columns,
    'Chi2 Stat': chi2_stat,
    'p-value': p_values
})

# %%
# Sort the results of the Chi-Square test by the 'Chi2 Stat' column in descending order
# This allows us to identify which features have the strongest association with the target variable.
chi2_results.sort_values(by='Chi2 Stat', ascending=False, inplace=True)
# Print the sorted Chi-Square test results for review
print("Chi-Square Test Results:")
print(chi2_results)
# Out:
# Chi-Square Test Results:
#                      Feature     Chi2 Stat        p-value
# 5      Monthly_Inhand_Salary  4.456226e+06   0.000000e+00
# 16          Outstanding_Debt  4.357053e+06   0.000000e+00
# 23           Monthly_Balance  3.622637e+06   0.000000e+00
# 4              Annual_Income  2.363972e+05   0.000000e+00
# 21   Amount_invested_monthly  1.735961e+05   0.000000e+00
# 11       Delay_from_due_date  5.505952e+04   0.000000e+00
# 9                Num_of_Loan  3.961277e+04   0.000000e+00
# 12    Num_of_Delayed_Payment  2.830720e+04   0.000000e+00
# 1                        Age  2.687638e+04   0.000000e+00
# 20       Total_EMI_per_month  2.155135e+04   0.000000e+00
# 13      Changed_Credit_Limit  1.813520e+04   0.000000e+00
# 18        Credit_History_Age  1.155297e+04   0.000000e+00
# 14      Num_Credit_Inquiries  6.302639e+03   0.000000e+00
# 6          Num_Bank_Accounts  4.014075e+03   0.000000e+00
# 7            Num_Credit_Card  1.974958e+03   0.000000e+00
# 8              Interest_Rate  8.695572e+02  4.072332e-191
# 19     Payment_of_Min_Amount  2.704393e+02   9.102727e-61
# 22         Payment_Behaviour  1.939338e+02   4.402670e-44
# 10              Type_of_Loan  9.317304e+01   4.791639e-22
# 17  Credit_Utilization_Ratio  3.555444e+01   2.480206e-09
# 15                Credit_Mix  3.553273e+01   2.508011e-09
# 2                        SSN  1.797916e+01   2.233368e-05
# 3                 Occupation  1.512407e+01   1.006715e-04
# 0                      Month  1.097680e+00   2.947757e-01

# %%
# Import necessary libraries for model evaluation
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
# Initialize variables to track the best accuracy, number of features, and corresponding feature set
best_accuracy = 0
best_k = 0
best_features = []
results=[]
# Initialize the Random Forest classifier with a fixed random state for reproducibility
clf = RandomForestClassifier(random_state=0)
# Loop over a range of k values to select the top k features based on the Chi-Square test
for k in range(1, X.shape[1] + 1):
    # Select the top k features using the Chi-Square test
    selector = SelectKBest(chi2, k=k)
    X_new = selector.fit_transform(X_transformed, y)
    # Get the names of the selected features
    selected_features = X_transformed.columns[selector.get_support()]

    print(f"\nTop {k} features selected based on Chi-Square test:")
    selected_features = list(selected_features)
    print(selected_features, end="\n\n")

    # Prepare the data with the selected features
    X_selected = df[selected_features].to_numpy()

    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X_selected, y,
                                                        test_size=0.3,
                                                        random_state=3,
                                                        shuffle=True)

    # Train the Random Forest classifier on the selected features
    clf.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred = clf.predict(X_test)

    # Calculate evaluation metrics: recall, precision, F1 score, and confusion matrix
    accuracy = metrics.recall_score(y_test, y_pred, average='weighted')
    precision = metrics.precision_score(y_test, y_pred, average='weighted')
    f1 = metrics.f1_score(y_test, y_pred, average='weighted')
    cm = confusion_matrix(y_test, y_pred)
    false_negatives = cm.sum(axis=1) - np.diag(cm)

    # Store results for the current k
    results.append({
        'num_features': k,
        'recall': accuracy,
        'precision': precision,
        'f1_score': f1,
        'false_negatives': false_negatives.sum()
    })

    #  Print the classification report for the current model
    print(f"Classification report for top {k} features:")
    print(classification_report(y_test, y_pred))
    print(f"{'------' * 9}")

# # Create a DataFrame from the collected results
results_df = pd.DataFrame(results)

# Save the results to a CSV file for later use
results_df.to_csv('feature_selection_comparison_chi2_project.csv', index=False)
# Print the best accuracy achieved and the corresponding number of features used
print(f"\nBest accuracy achieved: {results_df['recall'].max():.4f} with top {results_df.loc[results_df['recall'].idxmax(), 'num_features']} features.")
print(f"Best features: {best_features}")
# Out:
# Top 1 features selected based on Chi-Square test:
# ['Monthly_Inhand_Salary']
#
# Classification report for top 1 features:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.95      0.95      3770
#          1.0       0.90      0.88      0.89      1921
#
#     accuracy                           0.93      5691
#    macro avg       0.92      0.92      0.92      5691
# weighted avg       0.93      0.93      0.93      5691
#
# ------------------------------------------------------
#
# Top 2 features selected based on Chi-Square test:
# ['Monthly_Inhand_Salary', 'Outstanding_Debt']
#
# Classification report for top 2 features:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.95      0.96      3770
#          1.0       0.91      0.94      0.92      1921
#
#     accuracy                           0.95      5691
#    macro avg       0.94      0.95      0.94      5691
# weighted avg       0.95      0.95      0.95      5691
#
# ------------------------------------------------------
#
# Top 3 features selected based on Chi-Square test:
# ['Monthly_Inhand_Salary', 'Outstanding_Debt', 'Monthly_Balance']
#
# Classification report for top 3 features:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.86      0.90      3770
#          1.0       0.77      0.87      0.81      1921
#
#     accuracy                           0.87      5691
#    macro avg       0.85      0.87      0.86      5691
# weighted avg       0.87      0.87      0.87      5691
#
# ------------------------------------------------------
#
# Top 4 features selected based on Chi-Square test:
# ['Annual_Income', 'Monthly_Inhand_Salary', 'Outstanding_Debt', 'Monthly_Balance']
#
# Classification report for top 4 features:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.90      0.93      3770
#          1.0       0.83      0.91      0.87      1921
#
#     accuracy                           0.91      5691
#    macro avg       0.89      0.91      0.90      5691
# weighted avg       0.91      0.91      0.91      5691
#
# ------------------------------------------------------
#
# Top 5 features selected based on Chi-Square test:
# ['Annual_Income', 'Monthly_Inhand_Salary', 'Outstanding_Debt', 'Amount_invested_monthly', 'Monthly_Balance']
#
# Classification report for top 5 features:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.87      0.90      3770
#          1.0       0.78      0.90      0.83      1921
#
#     accuracy                           0.88      5691
#    macro avg       0.86      0.88      0.87      5691
# weighted avg       0.89      0.88      0.88      5691
#
# ------------------------------------------------------
#
# Top 6 features selected based on Chi-Square test:
# ['Annual_Income', 'Monthly_Inhand_Salary', 'Delay_from_due_date', 'Outstanding_Debt', 'Amount_invested_monthly', 'Monthly_Balance']
#
# Classification report for top 6 features:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.90      0.92      3770
#          1.0       0.82      0.89      0.85      1921
#
#     accuracy                           0.90      5691
#    macro avg       0.88      0.89      0.89      5691
# weighted avg       0.90      0.90      0.90      5691
#
# ------------------------------------------------------
#
# Top 7 features selected based on Chi-Square test:
# ['Annual_Income', 'Monthly_Inhand_Salary', 'Num_of_Loan', 'Delay_from_due_date', 'Outstanding_Debt', 'Amount_invested_monthly', 'Monthly_Balance']
#
# Classification report for top 7 features:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.90      0.92      3770
#          1.0       0.82      0.89      0.85      1921
#
#     accuracy                           0.90      5691
#    macro avg       0.88      0.90      0.89      5691
# weighted avg       0.90      0.90      0.90      5691
#
# ------------------------------------------------------
#
# Top 8 features selected based on Chi-Square test:
# ['Annual_Income', 'Monthly_Inhand_Salary', 'Num_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Outstanding_Debt', 'Amount_invested_monthly', 'Monthly_Balance']
#
# Classification report for top 8 features:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.90      0.92      3770
#          1.0       0.82      0.90      0.86      1921
#
#     accuracy                           0.90      5691
#    macro avg       0.88      0.90      0.89      5691
# weighted avg       0.90      0.90      0.90      5691
#
# ------------------------------------------------------
#
# Top 9 features selected based on Chi-Square test:
# ['Age', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Outstanding_Debt', 'Amount_invested_monthly', 'Monthly_Balance']
#
# Classification report for top 9 features:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.91      0.93      3770
#          1.0       0.83      0.91      0.87      1921
#
#     accuracy                           0.91      5691
#    macro avg       0.89      0.91      0.90      5691
# weighted avg       0.91      0.91      0.91      5691
#
# ------------------------------------------------------
#
# Top 10 features selected based on Chi-Square test:
# ['Age', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Outstanding_Debt', 'Total_EMI_per_month', 'Amount_invested_monthly', 'Monthly_Balance']
#
# Classification report for top 10 features:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.91      0.93      3770
#          1.0       0.84      0.91      0.88      1921
#
#     accuracy                           0.91      5691
#    macro avg       0.90      0.91      0.90      5691
# weighted avg       0.92      0.91      0.91      5691
#
# ------------------------------------------------------
#
# Top 11 features selected based on Chi-Square test:
# ['Age', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Outstanding_Debt', 'Total_EMI_per_month', 'Amount_invested_monthly', 'Monthly_Balance']
#
# Classification report for top 11 features:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.91      0.93      3770
#          1.0       0.85      0.91      0.88      1921
#
#     accuracy                           0.91      5691
#    macro avg       0.90      0.91      0.91      5691
# weighted avg       0.92      0.91      0.91      5691
#
# ------------------------------------------------------
#
# Top 12 features selected based on Chi-Square test:
# ['Age', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Outstanding_Debt', 'Credit_History_Age', 'Total_EMI_per_month', 'Amount_invested_monthly', 'Monthly_Balance']
#
# Classification report for top 12 features:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.92      0.94      3770
#          1.0       0.85      0.92      0.88      1921
#
#     accuracy                           0.92      5691
#    macro avg       0.90      0.92      0.91      5691
# weighted avg       0.92      0.92      0.92      5691
#
# ------------------------------------------------------
#
# Top 13 features selected based on Chi-Square test:
# ['Age', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Outstanding_Debt', 'Credit_History_Age', 'Total_EMI_per_month', 'Amount_invested_monthly', 'Monthly_Balance']
#
# Classification report for top 13 features:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.91      0.93      3770
#          1.0       0.84      0.92      0.88      1921
#
#     accuracy                           0.91      5691
#    macro avg       0.90      0.91      0.91      5691
# weighted avg       0.92      0.91      0.92      5691
#
# ------------------------------------------------------
#
# Top 14 features selected based on Chi-Square test:
# ['Age', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Outstanding_Debt', 'Credit_History_Age', 'Total_EMI_per_month', 'Amount_invested_monthly', 'Monthly_Balance']
#
# Classification report for top 14 features:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.91      0.94      3770
#          1.0       0.85      0.92      0.88      1921
#
#     accuracy                           0.92      5691
#    macro avg       0.90      0.92      0.91      5691
# weighted avg       0.92      0.92      0.92      5691
#
# ------------------------------------------------------
#
# Top 15 features selected based on Chi-Square test:
# ['Age', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Num_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Outstanding_Debt', 'Credit_History_Age', 'Total_EMI_per_month', 'Amount_invested_monthly', 'Monthly_Balance']
#
# Classification report for top 15 features:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.92      0.94      3770
#          1.0       0.86      0.92      0.89      1921
#
#     accuracy                           0.92      5691
#    macro avg       0.91      0.92      0.92      5691
# weighted avg       0.93      0.92      0.92      5691
#
# ------------------------------------------------------
#
# Top 16 features selected based on Chi-Square test:
# ['Age', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Outstanding_Debt', 'Credit_History_Age', 'Total_EMI_per_month', 'Amount_invested_monthly', 'Monthly_Balance']
#
# Classification report for top 16 features:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.92      0.94      3770
#          1.0       0.86      0.93      0.89      1921
#
#     accuracy                           0.93      5691
#    macro avg       0.91      0.93      0.92      5691
# weighted avg       0.93      0.93      0.93      5691
#
# ------------------------------------------------------
#
# Top 17 features selected based on Chi-Square test:
# ['Age', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Outstanding_Debt', 'Credit_History_Age', 'Payment_of_Min_Amount', 'Total_EMI_per_month', 'Amount_invested_monthly', 'Monthly_Balance']
#
# Classification report for top 17 features:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.93      0.94      3770
#          1.0       0.87      0.92      0.89      1921
#
#     accuracy                           0.93      5691
#    macro avg       0.91      0.93      0.92      5691
# weighted avg       0.93      0.93      0.93      5691
#
# ------------------------------------------------------
#
# Top 18 features selected based on Chi-Square test:
# ['Age', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Outstanding_Debt', 'Credit_History_Age', 'Payment_of_Min_Amount', 'Total_EMI_per_month', 'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance']
#
# Classification report for top 18 features:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.92      0.94      3770
#          1.0       0.86      0.93      0.89      1921
#
#     accuracy                           0.93      5691
#    macro avg       0.91      0.93      0.92      5691
# weighted avg       0.93      0.93      0.93      5691
#
# ------------------------------------------------------
#
# Top 19 features selected based on Chi-Square test:
# ['Age', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Outstanding_Debt', 'Credit_History_Age', 'Payment_of_Min_Amount', 'Total_EMI_per_month', 'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance']
#
# Classification report for top 19 features:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.93      0.94      3770
#          1.0       0.86      0.93      0.90      1921
#
#     accuracy                           0.93      5691
#    macro avg       0.91      0.93      0.92      5691
# weighted avg       0.93      0.93      0.93      5691
#
# ------------------------------------------------------
#
# Top 20 features selected based on Chi-Square test:
# ['Age', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age', 'Payment_of_Min_Amount', 'Total_EMI_per_month', 'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance']
#
# Classification report for top 20 features:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.92      0.94      3770
#          1.0       0.86      0.92      0.89      1921
#
#     accuracy                           0.92      5691
#    macro avg       0.91      0.92      0.92      5691
# weighted avg       0.93      0.92      0.92      5691
#
# ------------------------------------------------------
#
# Top 21 features selected based on Chi-Square test:
# ['Age', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age', 'Payment_of_Min_Amount', 'Total_EMI_per_month', 'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance']
#
# Classification report for top 21 features:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.92      0.94      3770
#          1.0       0.85      0.92      0.89      1921
#
#     accuracy                           0.92      5691
#    macro avg       0.91      0.92      0.91      5691
# weighted avg       0.92      0.92      0.92      5691
#
# ------------------------------------------------------
#
# Top 22 features selected based on Chi-Square test:
# ['Age', 'SSN', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age', 'Payment_of_Min_Amount', 'Total_EMI_per_month', 'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance']
#
# Classification report for top 22 features:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.93      0.94      3770
#          1.0       0.86      0.92      0.89      1921
#
#     accuracy                           0.93      5691
#    macro avg       0.91      0.92      0.92      5691
# weighted avg       0.93      0.93      0.93      5691
#
# ------------------------------------------------------
#
# Top 23 features selected based on Chi-Square test:
# ['Age', 'SSN', 'Occupation', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age', 'Payment_of_Min_Amount', 'Total_EMI_per_month', 'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance']
#
# Classification report for top 23 features:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.92      0.94      3770
#          1.0       0.86      0.92      0.89      1921
#
#     accuracy                           0.92      5691
#    macro avg       0.91      0.92      0.92      5691
# weighted avg       0.93      0.92      0.92      5691
#
# ------------------------------------------------------
#
# Top 24 features selected based on Chi-Square test:
# ['Month', 'Age', 'SSN', 'Occupation', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age', 'Payment_of_Min_Amount', 'Total_EMI_per_month', 'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance']
#
# Classification report for top 24 features:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.92      0.94      3770
#          1.0       0.86      0.92      0.89      1921
#
#     accuracy                           0.92      5691
#    macro avg       0.91      0.92      0.91      5691
# weighted avg       0.92      0.92      0.92      5691
#
# ------------------------------------------------------
#
# Best accuracy achieved: 0.9480 with top 2 features.
# Best features: []

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.2.2

# %%
# Define the feature set 'X' by selecting specific columns from the DataFrame 'df' that are relevant for model training.
# The target variable 'y' is defined as the 'Credit_Score' column from the DataFrame.
X=df[['Age', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Outstanding_Debt', 'Amount_invested_monthly', 'Monthly_Balance']]
y=df['Credit_Score']

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.3,        # Use 30% of the data for testing
                                                    random_state=3,      # Ensure reproducibility of the split
                                                    shuffle=True)        # Shuffle the data before splitting

# Get the lengths of the training and testing sets
len(X_train), len(X_test), len(y_train), len(y_test)  # Verify the sizes of the splits
# Out:
# (13277, 5691, 13277, 5691)

# %%
# Split the dataset into training and testing sets.
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.3,        # 30% of the data will be used for testing
                                                    random_state=3,      # Ensure reproducibility of the split
                                                    shuffle=True)        # Shuffle the data before splitting for randomness

# Output the lengths of the training and testing sets
len(X_train), len(X_test), len(y_train), len(y_test)  # Verify and display the sizes of the training and testing sets
# Out:
# (13277, 5691, 13277, 5691)

# %%
import numpy as np
from sklearn import metrics
from sklearn.metrics import RocCurveDisplay
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

def plot_confusion_matrix(cm, class_names, figsize=(15, 15), colorbar=True):
    """
    Plots a confusion matrix as a heatmap.
    """
    # Create a figure and axis for the plot
    fig, ax = plt.subplots(figsize=figsize)
    # Use seaborn's heatmap to plot the confusion matrix
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, 
                yticklabels=class_names, cbar=colorbar, ax=ax)
    ax.set_xlabel('Predicted')  # Set the x-axis label
    ax.set_ylabel('True')  # Set the y-axis label
    plt.title('Confusion Matrix')  # Set the title of the plot
    plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
    plt.show()  # Display the plot

def Evaluate(Model_Name, Model_Abb, X_test, Y_test):
    """
    Evaluates a multi-class classification model and prints metrics.
    """
    # Extract unique class names from the true labels
    class_names = np.unique(Y_test)

    # Predict class labels using the provided model
    Pred_Value = Model_Abb.predict(X_test)

    # Calculate various evaluation metrics
    Accuracy = metrics.accuracy_score(Y_test, Pred_Value)  # Calculate accuracy
    Sensitivity = metrics.recall_score(Y_test, Pred_Value, average='macro')  # Calculate sensitivity (recall)
    Precision = metrics.precision_score(Y_test, Pred_Value, average='macro')  # Calculate precision
    F1_score = metrics.f1_score(Y_test, Pred_Value, average='macro')  # Calculate F1 score
    Recall = metrics.recall_score(Y_test, Pred_Value, average='macro')  # Calculate recall

    # Print the evaluation metrics
    print('--------------------------------------------------\n')
    print('The {} Model Accuracy   = {}\n'.format(Model_Name, np.round(Accuracy, 3)))
    print('The {} Model Sensitivity = {}\n'.format(Model_Name, np.round(Sensitivity, 3)))
    print('The {} Model Precision  = {}\n'.format(Model_Name, np.round(Precision, 3)))
    print('The {} Model F1 Score   = {}\n'.format(Model_Name, np.round(F1_score, 3)))
    print('The {} Model Recall     = {}\n'.format(Model_Name, np.round(Recall, 3)))
    print('--------------------------------------------------\n')

    # Compute the confusion matrix
    Confusion_Matrix = metrics.confusion_matrix(Y_test, Pred_Value)
    # Plot the confusion matrix
    plot_confusion_matrix(Confusion_Matrix, class_names=class_names, figsize=(7, 7), colorbar=True)

    # Plot ROC Curve for each class
    plt.figure(figsize=(10, 7))  # Set the figure size for the ROC curve plot
    for i in range(len(class_names)):
        # Display ROC curve for each class
        RocCurveDisplay.from_predictions(Y_test == class_names[i], Pred_Value == class_names[i], 
                                         name=str(class_names[i]), ax=plt.gca())
    plt.title('ROC Curve')  # Set the title for the ROC curve plot
    plt.show()  # Display the ROC curve plot

# %%
# Initialize the Logistic Regression model
LR = LogisticRegression()

# Fit the Logistic Regression model to the training data, using 'X_train' as the feature set and 'y_train' as the target variable.
LR.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Evaluate the Logistic Regression model
Evaluate('Logistic Regression', LR, X_test, y_test)
# Out:
# --------------------------------------------------
#
# The Logistic Regression Model Accuracy   = 0.829
#
# The Logistic Regression Model Sensitivity = 0.807
#
# The Logistic Regression Model Precision  = 0.809
#
# The Logistic Regression Model F1 Score   = 0.808
#
# The Logistic Regression Model Recall     = 0.807
#
# --------------------------------------------------

# %%
# Initialize the Decision Tree Classifier
DT =DecisionTreeClassifier( max_depth=20,random_state=42,criterion='entropy')
# Fit the Decision Tree Classifier
DT.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=20, random_state=42)

# %%
# Evaluate the Decision Tree Classifier
Evaluate('Decision Tree Classifier', DT, X_test, y_test)
# Out:
# --------------------------------------------------
#
# The Decision Tree Classifier Model Accuracy   = 0.872
#
# The Decision Tree Classifier Model Sensitivity = 0.868
#
# The Decision Tree Classifier Model Precision  = 0.854
#
# The Decision Tree Classifier Model F1 Score   = 0.86
#
# The Decision Tree Classifier Model Recall     = 0.868
#
# --------------------------------------------------

# %%
# Initialize the Random Forest Classifier
RF = RandomForestClassifier(max_depth=70)

# Train the Random Forest model on the training data
RF.fit(X_train, y_train)

# Evaluate the performance of the Random Forest model
Evaluate('Random Forest Classifier', RF, X_test, y_test)
# Out:
# --------------------------------------------------
#
# The Random Forest Classifier Model Accuracy   = 0.904
#
# The Random Forest Classifier Model Sensitivity = 0.904
#
# The Random Forest Classifier Model Precision  = 0.888
#
# The Random Forest Classifier Model F1 Score   = 0.895
#
# The Random Forest Classifier Model Recall     = 0.904
#
# --------------------------------------------------

# %%
# Initialize the K-Nearest Neighbors Classifier
KNN = KNeighborsClassifier(n_neighbors=10)

# Train the K-Nearest Neighbors model on the training data
KNN.fit(X_train, y_train)

# Evaluate the performance of the K-Nearest Neighbors model
Evaluate('KNN', KNN, X_test, y_test)
# Out:
# --------------------------------------------------
#
# The KNN Model Accuracy   = 0.804
#
# The KNN Model Sensitivity = 0.787
#
# The KNN Model Precision  = 0.781
#
# The KNN Model F1 Score   = 0.784
#
# The KNN Model Recall     = 0.787
#
# --------------------------------------------------

# %% [markdown]
# # pipe line and cross validation(5)

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
# Define the pipeline steps
pipeline = Pipeline([
    ('scaler', StandardScaler()),  # Step 1: Standardize features
    ('pca', PCA(n_components=2)),  # Step 2: Reduce dimensions using PCA
    ('classifier', RandomForestClassifier(n_estimators=100, random_state=42))  # Step 3: Classifier
])

# Perform cross-validation
cv_scores = cross_val_score(pipeline, X, y, cv=5, scoring='accuracy')

# Print cross-validation results
print(f"Cross-Validation Scores: {cv_scores}")
print(f"Mean Accuracy: {cv_scores.mean():.2f}")
# Out:
# Cross-Validation Scores: [0.79045862 0.78808645 0.79098577 0.79514896 0.78275771]
# Mean Accuracy: 0.79

# %%
# Instantiate the Gradient Boosting Classifier with default parameters
GB = GradientBoostingClassifier()

# Train the Gradient Boosting Classifier on the training data
GB.fit(X_train, y_train)

# Evaluate the performance of the Gradient Boosting Classifier
Evaluate('Gradient Boosting Classifier', GB, X_test, y_test)
# Out:
# --------------------------------------------------
#
# The Gradient Boosting Classifier Model Accuracy   = 0.871
#
# The Gradient Boosting Classifier Model Sensitivity = 0.869
#
# The Gradient Boosting Classifier Model Precision  = 0.852
#
# The Gradient Boosting Classifier Model F1 Score   = 0.859
#
# The Gradient Boosting Classifier Model Recall     = 0.869
#
# --------------------------------------------------

# %%
#! pip install tensorflow

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import joblib
y = to_categorical(y)

# %%
from keras.layers import Dense, BatchNormalization, Dropout
from keras.models import Sequential

model = Sequential([

    # Input normalization
    BatchNormalization(input_dim=X.shape[1]),

    # Hidden layer 1: 500 neurons with ReLU activation
    Dense(500, activation='relu'),

    # Dropout layer 1: 10% dropout rate
    Dropout(0.1),

    # Batch normalization layer 2
    BatchNormalization(),

    # Hidden layer 2: 400 neurons with ReLU activation
    Dense(400, activation='relu'),

    # Dropout layer 2: 30% dropout rate
    Dropout(0.3),

    # Batch normalization layer 3
    BatchNormalization(),

    # Hidden layer 3: 200 neurons with ReLU activation
    Dense(200, activation='relu'),

    # Batch normalization layer 4
    BatchNormalization(),

    # Hidden layer 4: 100 neurons with ReLU activation
    Dense(100, activation='relu'),

    # Dropout layer 3: 35% dropout rate
    Dropout(0.35),

    # Batch normalization layer 5
    BatchNormalization(),

    # Hidden layer 5: 50 neurons with ReLU activation
    Dense(50, activation='relu'),

    # Batch normalization layer 6
    BatchNormalization(),

    # Output layer: 2 neurons with sigmoid activation (for binary classification)
    Dense(2, activation='sigmoid')

])

# %%
# Compile the model
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics=['accuracy'])

# %%
# Define early stopping
early_stop = EarlyStopping(monitor='accuracy', patience=3, restore_best_weights=True)

# Train the model
history = model.fit(X, y, validation_split=0.3, epochs=20, callbacks=[early_stop], batch_size=128)
# Out:
# Epoch 1/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7816 - loss: 0.5299 - val_accuracy: 0.7443 - val_loss: 0.4747
# Epoch 2/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8404 - loss: 0.3808 - val_accuracy: 0.8174 - val_loss: 0.3921
# Epoch 3/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8537 - loss: 0.3434 - val_accuracy: 0.8524 - val_loss: 0.3369
# Epoch 4/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8555 - loss: 0.3389 - val_accuracy: 0.8556 - val_loss: 0.3295
# Epoch 5/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8512 - loss: 0.3335 - val_accuracy: 0.8568 - val_loss: 0.3280
# Epoch 6/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8533 - loss: 0.3379 - val_accuracy: 0.8587 - val_loss: 0.3272
# Epoch 7/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8582 - loss: 0.3217 - val_accuracy: 0.8578 - val_loss: 0.3323
# Epoch 8/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8599 - loss: 0.3271 - val_accuracy: 0.8605 - val_loss: 0.3258
# Epoch 9/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8638 - loss: 0.3177 - val_accuracy: 0.8593 - val_loss: 0.3274
# Epoch 10/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8566 - loss: 0.3275 - val_accuracy: 0.8585 - val_loss: 0.3241
# Epoch 11/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8578 - loss: 0.3207 - val_accuracy: 0.8573 - val_loss: 0.3278

# %%
import matplotlib.pyplot as plt

# Extracting the training history
history_dict = history.history

# Plotting training accuracy vs validation accuracy
plt.figure(figsize=(12, 5))  # Create a figure with specified dimensions

# Accuracy
plt.subplot(1, 2, 1)  # Create a subplot occupying the top-left portion of the figure
plt.plot(history_dict['accuracy'], label='Training Accuracy')
plt.plot(history_dict['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()  # Add a legend to distinguish between the lines

# Loss
plt.subplot(1, 2, 2)  # Create a subplot occupying the top-right portion of the figure
plt.plot(history_dict['loss'], label='Training Loss')
plt.plot(history_dict['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()  # Add a legend to distinguish between the lines

plt.show()  # Display the plotted figure

# %% [markdown]
# ensempling (vooting score)

# %%
from sklearn.ensemble import VotingClassifier
# Create the Voting Classifier (using soft voting in this example)
voting_clf = VotingClassifier(
    estimators=[
        ('DT', DT),
        ('clf', RF),
        ('KNN', KNN),
    ],
    voting='soft' , # Change to 'hard' for hard voting
    weights=[2, 4, 2]
)

# Train the Voting Classifier
voting_clf.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('DT',
#                               DecisionTreeClassifier(criterion='entropy',
#                                                      max_depth=20,
#                                                      random_state=42)),
#                              ('clf', RandomForestClassifier(max_depth=70)),
#                              ('KNN', KNeighborsClassifier(n_neighbors=10))],
#                  voting='soft', weights=[2, 4, 2])

# %%
Evaluate('The VOOTING Classifier', voting_clf, X_test, y_test)
# Out:
# --------------------------------------------------
#
# The The VOOTING Classifier Model Accuracy   = 0.897
#
# The The VOOTING Classifier Model Sensitivity = 0.898
#
# The The VOOTING Classifier Model Precision  = 0.88
#
# The The VOOTING Classifier Model F1 Score   = 0.888
#
# The The VOOTING Classifier Model Recall     = 0.898
#
# --------------------------------------------------

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, classification_report, confusion_matrix

# Function to compare models
def compare_models(models, X_train, X_test, y_train, y_test):
    results = []
    for model, name in models:
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        accuracy = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred, average='weighted')
        recall = recall_score(y_test, y_pred, average='weighted')
        precision = precision_score(y_test, y_pred, average='weighted')
        cm = confusion_matrix(y_test, y_pred)
        report = classification_report(y_test, y_pred)
        results.append({
            'model_name': name,
            'accuracy': accuracy,
            'f1': f1,
            'recall': recall,
            'precision': precision,
            'confusion_matrix': cm,
            'classification_report': report
        })
    return results

# Define your models
models = [
    (RF, 'Random Forest'),
    (KNN, 'KNN'),
    (DT, 'SVC'),
    (LR,'LogisticRegression'),
    (GB, 'Gradient Boosting'),
    (voting_clf, 'Voting Classifier')
]

# Compare the models
results = compare_models(models, X_train, X_test, y_train, y_test)

# Create a dataframe for comparison
results_df = pd.DataFrame({
    'Model': [result['model_name'] for result in results],
    'Accuracy': [result['accuracy'] for result in results],
    'F1 Score': [result['f1'] for result in results],
    'Recall': [result['recall'] for result in results],
    'Precision': [result['precision'] for result in results]
})

# Melt the dataframe for easier plotting
results_melted = results_df.melt(id_vars='Model', var_name='Metric', value_name='Value')

# Print comparison table
print("## Comparison Table")
print(results_df)

# Plot comparison
plt.figure(figsize=(12, 8))
sns.barplot(x='Model', y='Value', hue='Metric', data=results_melted)
plt.title('Model Comparison')
plt.legend(loc='upper right')
plt.show()

# Print confusion matrices and classification reports
for result in results:
    print(f"## {result['model_name']} Confusion Matrix and Classification Report")
    print(result['confusion_matrix'])
    print(result['classification_report'])
# Out:
# ## Comparison Table
#                 Model  Accuracy  F1 Score    Recall  Precision
# 0       Random Forest  0.904410  0.905427  0.904410   0.908564
# 1                 KNN  0.804428  0.805430  0.804428   0.806805
# 2                 SVC  0.872079  0.873301  0.872079   0.876115
# 3  LogisticRegression  0.829204  0.828916  0.829204   0.828664
# 4   Gradient Boosting  0.870673  0.872160  0.870673   0.876067
# 5   Voting Classifier  0.896328  0.897529  0.896328   0.901285
# ## Random Forest Confusion Matrix and Classification Report
# [[3403  367]
#  [ 177 1744]]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.90      0.93      3770
#          1.0       0.83      0.91      0.87      1921
#
#     accuracy                           0.90      5691
#    macro avg       0.89      0.91      0.90      5691
# weighted avg       0.91      0.90      0.91      5691
#
# ## KNN Confusion Matrix and Classification Report
# [[3171  599]
#  [ 514 1407]]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.84      0.85      3770
#          1.0       0.70      0.73      0.72      1921
#
#     accuracy                           0.80      5691
#    macro avg       0.78      0.79      0.78      5691
# weighted avg       0.81      0.80      0.81      5691
#
# ## SVC Confusion Matrix and Classification Report
# [[3322  448]
#  [ 280 1641]]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.88      0.90      3770
#          1.0       0.79      0.85      0.82      1921
#
#     accuracy                           0.87      5691
#    macro avg       0.85      0.87      0.86      5691
# weighted avg       0.88      0.87      0.87      5691
#
# ## LogisticRegression Confusion Matrix and Classification Report
# [[3297  473]
#  [ 499 1422]]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.87      0.87      3770
#          1.0       0.75      0.74      0.75      1921
#
#     accuracy                           0.83      5691
#    macro avg       0.81      0.81      0.81      5691
# weighted avg       0.83      0.83      0.83      5691
#
# ## Gradient Boosting Confusion Matrix and Classification Report
# [[3298  472]
#  [ 264 1657]]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.87      0.90      3770
#          1.0       0.78      0.86      0.82      1921
#
#     accuracy                           0.87      5691
#    macro avg       0.85      0.87      0.86      5691
# weighted avg       0.88      0.87      0.87      5691
#
# ## Voting Classifier Confusion Matrix and Classification Report
# [[3370  400]
#  [ 190 1731]]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.89      0.92      3770
#          1.0       0.81      0.90      0.85      1921
#
#     accuracy                           0.90      5691
#    macro avg       0.88      0.90      0.89      5691
# weighted avg       0.90      0.90      0.90      5691

# %% [markdown]
# End of ML

# %%
! pip install pipeline_Knn
# Out:
# ERROR: Could not find a version that satisfies the requirement pipeline_Knn (from versions: none)
# ERROR: No matching distribution found for pipeline_Knn

# %%
! pip install joblib
# Out:
# Requirement already satisfied: joblib in d:\temp\txgamedownload\component\anaconda\lib\site-packages (1.2.0)

# %% [markdown]
# # Deployment

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
import joblib

# Define your pipeline
pipeline_Knn = Pipeline([
    ('scaler', StandardScaler()),  # Optional: Scale features
    ('knn', KNeighborsClassifier(n_neighbors=5))  # Adjust n_neighbors as needed
])

# Assuming X_train and y_train are your training data and labels
pipeline_Knn.fit(X_train, y_train)

# Now you can save the trained pipeline
joblib.dump(pipeline_Knn, 'pipeline_Knn.pkl')
# Out:
# ['pipeline_Knn.pkl']

# %%
import joblib

# Save the trained model to a .pkl file using joblib
joblib.dump(clf, 'random_forest_model1.pkl')
# Out:
# ['random_forest_model1.pkl']
